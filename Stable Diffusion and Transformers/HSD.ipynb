# %%
from PIL import Image
from io import BytesIO
import requests

# %%
import matplotlib.pyplot as plt

# %%
import requests
import torch
from PIL import Image
from io import BytesIO

from diffusers import StableDiffusionImg2ImgPipeline

device = "cpu"
model_id_or_path = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(model_id_or_path)
pipe = pipe.to(device)

url = "https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_1280,q_80/lsci/db/PICTURES/CMS/231900/231903.jpg"

response = requests.get(url)
init_image = Image.open(BytesIO(response.content)).convert("RGB")

prompt = "Virat Kohli in his cover drive position "

images = pipe(prompt=prompt, image=init_image).images[0]
# Out:
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
print("[PROMPT] :", prompt)
plt.imshow(images)
plt.style.use('dark_background')
plt.axis("off")
# Out:
# [PROMPT] : An AI generated realistic avatar of Narendra Modi giving speech about National Budget
# (-0.5, 1023.5, 1023.5, -0.5)

# %%
import requests
import torch
from PIL import Image
from io import BytesIO

from diffusers import StableDiffusionImg2ImgPipeline
device = "cpu"
model_id_or_path = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained(model_id_or_path)
pipe = pipe.to(device)

url = "https://images.mid-day.com/images/images/2016/mar/18MS-Dhoni-1.jpg"

response = requests.get(url)
init_image = Image.open(BytesIO(response.content)).convert("RGB")

prompt = "An AI generated realistic avatar of the image of Mahendra Singh Dhoni holding world cup trophy "

images = pipe(prompt=prompt, image=init_image).images[0]
# Out:
# ...
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
print("[PROMPT] :", prompt)
plt.imshow(images)
plt.style.use('dark_background')
plt.axis("off")
# Out:
# [PROMPT] : An AI generated realistic avatar of the image of Mahendra Singh Dhoni holding world cup trophy
# (-0.5, 663.5, 647.5, -0.5)
